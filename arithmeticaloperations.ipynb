# %%
# addition
import pandas as pd
def addition(a,b):
    print(a+b)
addition(5,4)
# Out:
# 9

# %%
# modulus
def modulus(a,b):
   print(a%b)
modulus(10,5)
# Out:
# 0

# %%
#floor division
def floor_division(a,b):
    if b==0:
        return "division by zero not allowed"
    return a//b
print(floor_division(5.6,3.1))
# Out:
# 1.0
